# %% [markdown]
# ## Bag of Word

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'text':['people watch campusX', 'campusX watch campusX', 'people write comment','campusX write comment'],
                   'output':[1,0,1,0,]})
df.head()
# Out:
#                     text  output
# 0   people watch campusX       1
# 1  campusX watch campusX       0
# 2   people write comment       1
# 3  campusX write comment       0

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
bow = cv.fit_transform(df['text']).toarray()

# %%
print(cv.vocabulary_)
# Out:
# {'people': 2, 'watch': 3, 'campusx': 0, 'write': 4, 'comment': 1}

# %%
cv.transform(['campusX watch and write comment of campusX']).toarray()
# Out:
# array([[2, 1, 0, 1, 1]])

# %% [markdown]
# ### On real dataset

# %%
df = pd.read_csv('cleaned_train.csv', nrows=1000 , usecols=['label', 'tweet'])
df.head()
# Out:
#    label                                              tweet
# 0      0  user when a father be dysfunctional and be so ...
# 1      0  user user thanks for lyft credit i cant use ca...
# 2      0                                bihday your majesty
# 3      0  model i love u take with u all the time in urð...
# 4      0                  factsguide society now motivation

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(df['tweet']).toarray()
X.shape
# Out:
# (1000, 3694)

# %%
print(cv.vocabulary_)
# Out:
# {'user': 3411, 'when': 3538, 'father': 1184, 'be': 355, 'dysfunctional': 1013, 'and': 208, 'so': 2974, 'selfish': 2853, 'he': 1507, 'drag': 986, 'his': 1552, 'kid': 1810, 'into': 1721, 'dysfunction': 1012, 'run': 2783, 'thanks': 3211, 'for': 1271, 'lyft': 1992, 'credit': 790, 'cant': 583, 'use': 3409, 'cause': 606, 'they': 3242, 'dont': 974, 'offer': 2317, 'wheelchair': 3537, 'van': 3426, 'in': 1656, 'pdx': 2432, 'disapointed': 933, 'getthanked': 1358, 'bihday': 411, 'your': 3644, 'majesty': 2010, 'model': 2132, 'love': 1955, 'take': 3154, 'with': 3571, 'all': 166, 'the': 3215, 'time': 3270, 'urð': 3406, 'factsguide': 1156, 'society': 2979, 'now': 2296, 'motivation': 2161, '22': 39, 'huge': 1599, 'fan': 1169, 'fare': 1176, 'big': 404, 'talk': 3157, 'before': 373, 'leave': 1873, 'chaos': 627, 'pay': 2427, 'dispute': 946, 'get': 1356, 'there': 3233, 'allshowandnogo': 171, 'camp': 573, 'tomorrow': 3289, 'dannyâ': 850, 'next': 2251, 'school': 2826, 'year': 3629, 'examsð': 1125, 'think': 3246, 'about': 105, 'that': 3212, 'exam': 1123, 'hate': 1492, 'imagine': 1649, 'actorslife': 118, 'revolutionschool': 2731, 'girl': 1366, 'we': 3495, 'won': 3580, 'land': 1844, 'allin': 168, 'cavs': 608, 'champion': 620, 'cleveland': 682, 'clevelandcavaliers': 683, 'welcome': 3518, 'here': 1534, 'im': 1646, 'it': 1739, 'gr8': 1411, 'ireland': 1727, 'consumer': 750, 'price': 2557, 'index': 1668, 'mom': 2136, 'climbed': 687, 'from': 1310, 'previous': 2555, '02': 0, 'to': 3278, '05': 1, 'may': 2054, 'blog': 455, 'silver': 2918, 'g