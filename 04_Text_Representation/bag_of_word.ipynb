# %% [markdown]
# ## Bag of Word

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'text':['people watch campusX', 'campusX watch campusX', 'people write comment','campusX write comment'],
                   'output':[1,0,1,0,]})
df.head()
# Out:
#                     text  output
# 0   people watch campusX       1
# 1  campusX watch campusX       0
# 2   people write comment       1
# 3  campusX write comment       0

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range=(1,2))
bow = cv.fit_transform(df['text']).toarray()

# %%
print(cv.vocabulary_)
# Out:
# {'people': 4, 'watch': 7, 'campusx': 0, 'people watch': 5, 'watch campusx': 8, 'campusx watch': 1, 'write': 9, 'comment': 3, 'people write': 6, 'write comment': 10, 'campusx write': 2}

# %%
cv.transform(['campusX watch and write comment of campusX']).toarray()
# Out:
# array([[2, 1, 0, 1, 0, 0, 0, 1, 0, 1, 1]])

# %% [markdown]
# ### On real dataset

# %%
df = pd.read_csv('cleaned_train.csv', nrows=1000 , usecols=['label', 'tweet'])
df.head()
# Out:
#    label                                              tweet
# 0      0  user when a father be dysfunctional and be so ...
# 1      0  user user thanks for lyft credit i cant use ca...
# 2      0                                bihday your majesty
# 3      0  model i love u take with u all the time in urð...
# 4      0                  factsguide society now motivation

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range=(3,3))
X = cv.fit_transform(df['tweet']).toarray()
X.shape
# Out:
# (1000, 9385)

# %%
print(cv.vocabulary_)
# Out:
# {'user when father': 8452, 'when father be': 8820, 'father be dysfunctional': 2351, 'be dysfunctional and': 856, 'dysfunctional and be': 2094, 'and be so': 411, 'be so selfish': 998, 'so selfish he': 6612, 'selfish he drag': 6378, 'he drag his': 3302, 'drag his kid': 2061, 'his kid into': 3422, 'kid into his': 4040, 'into his dysfunction': 3806, 'his dysfunction run': 3418, 'user user thanks': 8424, 'user thanks for': 8362, 'thanks for lyft': 7006, 'for lyft credit': 2601, 'lyft credit cant': 4450, 'credit cant use': 1719, 'cant use cause': 1458, 'use cause they': 8093, 'cause they dont': 1485, 'they dont offer': 7443, 'dont offer wheelchair': 2033, 'offer wheelchair van': 5371, 'wheelchair van in': 8816, 'van in pdx': 8495, 'in pdx disapointed': 3692, 'pdx disapointed getthanked': 5699, 'bihday your majesty': 1207, 'model love take': 4691, 'love take with': 4398, 'take with all': 6898, 'with all the': 8950, 'all the time': 273, 'the time in': 7311, 'time in urð': 7586, 'factsguide society now': 2296, 'society now motivation': 6641, '22 huge fan': 54, 'huge fan fare': 3524, 'fan fare and': 2326, 'fare and big': 2343, 'and big talk': 412, 'big talk before': 1176, 'talk before they': 6905, 'before they leave': 1127, 'they leave chaos': 7452, 'leave chaos and': 4151, 'chaos and pay': 1508, 'and pay dispute': 476, 'pay dispute when': 5690, 'dispute when they': 1944, 'when they get': 8834, 'they get there': 7446, 'get there allshowandnogo': 2884, 'user camp tomorrow': 8161, 'camp tomorrow user': 1424, 'tomorrow user user': 7901, 'user user user': 8429, 'user user dannyâ': 8400, 'the next school': 7226, 'next school year': 5057, 'school year be': 6321, 'year be the': 9119, 'be the year': 1022, 'the year for': 7359, 'year for examsð': 9120, 'for examsð cant': 2569, 'examsð cant think': 2255, 'cant think about': 1457, 'think about that': 7473, 'about that school': 131, 'that school exam': 7051, 'school exam hate': 6319, 'exam hate imagine': 2252, 'hate imagine actorslife': 3211, 'imagine actorslife revolutionschool': 3629, 'actorslife revolutionschool girl': 160, 'we won love': 8715, 'won love the': 9021, 'love the land': 4400, 'the land allin': 7185, 'land allin cavs': 4102, 'allin cavs champion': 282, 'cavs champion cleveland': 1487, 'champion cleveland clevelandcavaliers': 1499, 'user user welcome': 8431, 'user welcome here': 8447, 'welcome here im': 8761, 'here im it': 3378, 'im it so': 3605, 'it so gr8': 3890, 'ireland consumer price': 3815, 'consumer price index': 1674, 'price index mom': 5909, 'index mom climbed': 3755, 'mom climbed from': 4697, 'climbed from previous': 1584, 'from previous 02': 2772, 'previous 02 to': 5906, '02 to 05': 1, 'to 05 in': 7603, '05 in may': 2, 'in may blog': 3677, 'may blog silver': 4551, 'blog silver gold': 1259, 'silver gold forex': 6498, 'we be so': 8679, 'so selfish orlando': 6613, 'selfish orlando standwithorlando': 6380, 'orlando standwithorlando pulseshooting': 5556, 'standwithorlando pulseshooting orlandoshooting': 6718, 'pulseshooting orlandoshooting biggerproblems': 5953, 'orlandoshooting biggerproblems selfish': 5558, 'biggerproblems selfish heabreaking': 1180, 'selfish heabreaking value': 6379, 'heabreaking value love': 3321, 'get to see': 2888, 'to see my': 7797, 'see my daddy': 6350, 'my daddy today': 4864, 'daddy today 80days': 1779, 'today 80days gettingfed': 7868, 'user cnn call': 8167, 'cnn call michigan': 1593, 'call michigan middle': 1415, 'michigan middle school': 4643, 'middle school build': 4644, 'school build the': 6318, 'build the wall': 1348, 'the wall chant': 7338, 'wall chant tcot': 8613, 'no comment in': 5095, 'comment in australia': 1630, 'in australia opkillingbay': 3646, 'australia opkillingbay seashepherd': 709, 'opkillingbay seashepherd helpcovedolphins': 5518, 'seashepherd helpcovedolphins thecove': 6335, 'helpcovedolphins thecove helpcovedolphins': 3356, 'ouchjunior be angryð': 5570, 'be angryð got7': 823, 'angryð got7 junior': 544, 'got7 junior yugyoem': 3022, ' ...
