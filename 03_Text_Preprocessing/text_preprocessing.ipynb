# %% [markdown]
# # Text Pre-Processing

# %%
# Import libraries
import pandas as pd

# %%
# Load dataset
df = pd.read_csv('IMDB Dataset.csv')
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ##### Lower casing

# %%
# lower case
df['review'] = df['review'].str.lower()
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# ##### remove html tags

# %%
# Remove Html tags
import re
def remove_html_tags(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)
df['review'] = df['review'].apply(lambda text: remove_html_tags(text))
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. the filming tec...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %%
def remove_url(text) :
    pattern = re.compile(r'https?://\S+|www\.\S+')
    return pattern.sub(r'', text)

# %%
text = 'Check out my notebook https://www.kaggle.com/campusx/notebook8223fc1abb'
text2 = 'Check out my notebook http:/ /www.kaggle.com/campusx/notebook8223fc1abb'
text3 = 'Google search here www.google.com'
text4 = 'For notebook click "https://www.kaggle.com/campusx/notebook8223fclabb" to search check www.google.com'

# %%
remove_url(text)
# Out:
# 'Check out my notebook '

# %%
remove_url(text2)
# Out:
# 'Check out my notebook http:/ /'

# %% [markdown]
# ##### Remove Punctuation

# %%
import string
exclude = string.punctuation

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punc(text):
     return text.translate(str.maketrans('', '', exclude))

# %%
text = 'Hi, how are you? Where: You are! :)() Are you OK?// ahh/'

# %%
remove_punc(text)
# Out:
# 'Hi how are you Where You are  Are you OK ahh'

# %%
df2 = pd.read_csv('twitter_data/train.csv')

# %%
df2.sample(5)
# Out:
#           id  label                                              tweet
# 3060    3061      0  #saturday #morning #blessedramadan   very good...
# 12732  12733      0                       father's day! #googledoodle
# 9113    9114      0  be   be #beautiful  #mymaceeleighlife #mymllif...
# 7316    7317      0           can't wait to sta college   #collegelife
# 20257  20258      0  working on song 3 of my #ep  !   #musicisthera...

# %%
df2['tweet'] = df['tweet'].apply(remove_punc)

# %%
df2.head(5)
# Out:
#    id  label                                              tweet
# 0   1      0   user when a father is dysfunctional and is so...
# 1   2      0  user user thanks for lyft credit i cant use ca...
# 2   3      0                                bihday your majesty
# 3   4      0  model   i love u take with u all the time in u...
# 4   5      0               factsguide society now    motivation

# %% [markdown]
# ##### Spelling Correction

# %%
from textblob import TextBlob

# %%
incorrect_text = 'howw arre yoou, whatt ari yyu doiing?'
blob = TextBlob(incorrect_text)
blob.correct().string
# Out:
# 'how are you, what are you doing?'

# %% [markdown]
# ##### Remove Stopwords

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
def remove_stopwords(text):
    new_text = []
    for word in text.split():
        if word not in stopwords.words('english'):
            new_text.append(word)
    return " ".join(new_text)

# %%
remove_stopwords("The quick brown fox jumps over the lazy dog.")
# Out:
# 'The quick brown fox jumps lazy dog.'

# %% [markdown]
# ##### Handle Emojis

# %%
import re 
def remove_emoji(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# %%
emoji_text = 'that was amazing, 👍👍👍'
remove_emoji(emoji_text)
# Out:
# 'that was amazing, '

# %%
import emoji 
def demojize(text):
    return emoji.demojize(text)

# %%
demojize('that was amazing, 👍')
# Out:
# 'that was amazing, :thumbs_up:'

# %%
demojize('Python is 🔥')
# Out:
# 'Python is :fire:'

# %%
demojize('Love this 😘')
# Out:
# 'Love this :face_blowing_a_kiss:'

# %% [markdown]
# ### Tokenization
